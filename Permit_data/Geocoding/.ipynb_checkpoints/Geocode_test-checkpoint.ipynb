# %%
import requests
import numpy as np
import pandas as pd
import herepy
# store your herepy API key in a file "config.py" as api_key = "xyz"
import config
import json
import re

# %%
# tell the API to use your key
geocoderApi = herepy.GeocoderApi(config.api_key)

# read in data to be geocoded (in this case voter data)
voters = pd.read_csv("voter_list.csv")

# %%
geocoderApi

# %%
voters.head(10)
# Out:
#              ID IsActive                 Name  \
# 0  001384287-02        A      EDWARD T LEHENY
# 1  001395718-02        I  LAWRENCE J ZIGERELL
# 2  001405849-02        A          JOHN W MADL
# 3  001595964-02        A    JEFFREY A SCHWARZ
# 4  001530986-02        I    PAUL JOYA ALARCON
# 5  001919470-02        A    FRANCIS E FAIRMAN
# 6  001919955-02        A  WILLIAM P KRAKOVSKY
# 7  001912448-02        A      RAYMOND H SMITH
# 8  001539723-02        A  ARNOLD E BURCHIANTI
# 9  001921302-02        A       HENRY E HALLER
#
#                                              Address      Home Phone  \
# 0  6589  ROSEMOOR ST APT. UPPR\nPITTSBURGH, PA  1...             NaN
# 1            5700  CENTRE AVE\nPITTSBURGH, PA  15206  (724) 561-5280
# 2            4136  BRISTOL ST\nPITTSBURGH, PA  15207             NaN
# 3              306  SALINE ST\nPITTSBURGH, PA  15207             NaN
# 4         6310  DARLINGTON RD\nPITTSBURGH, PA  15217             NaN
# 5           719  AMBERSON AVE\nPITTSBURGH, PA  15232             NaN
# 6         938  GREENFIELD AVE\nPITTSBURGH, PA  15217  (412) 421-9175
# 7    825  MOREWOOD AVE APT. D\nPITTSBURGH, PA  15213             NaN
# 8              1074  DEVON RD\nPITTSBURGH, PA  15213             NaN
# 9               5615  HOWE ST\nPITTSBURGH, PA  15232  (412) 361-6797
#
#   Registration\nDate         DOB Party     County
# 0         10/07/1996  08/23/1978     D  ALLEGHENY
# 1         02/27/1992  11/19/1973     R  ALLEGHENY
# 2         01/13/1997  12/17/1954     R  ALLEGHENY
# 3         09/26/2003  09/17/1975     D  ALLEGHENY
# 4         10/08/2002  09/28/1944     R  ALLEGHENY
# 5         08/01/1968  05/30/1923     R  ALLEGHENY
# 6         02/01/1968  12/04/1946    NF  ALLEGHENY
# 7         09/01/1964  01/27/1943     D  ALLEGHENY
# 8         06/18/1998  06/15/1970     R  ALLEGHENY
# 9         09/01/1968  02/25/1947    LN  ALLEGHENY

# %%
# make addresses a list
addresses = voters['Address'].tolist()
# remove line breaks within addresses
addresses = [re.sub('\\n',', ',a) for a in addresses]

# %%
addresses[:3]
# Out:
# ['6589  ROSEMOOR ST APT. UPPR, PITTSBURGH, PA  15217',
#  '5700  CENTRE AVE, PITTSBURGH, PA  15206',
#  '4136  BRISTOL ST, PITTSBURGH, PA  15207']

# %%
# run the geocoder on addresses, currently set to only run on 10 addresses
geocode_responses = []
#for i in range(0,len(addresses):
for i in range(0,10):
    response = geocoderApi.free_form(addresses[i])
    geocode_responses.append(response.as_dict())

# %%
geocode_responses[0]
# Out:
# {'items': [{'title': '6589 Rosemoor St, Pittsburgh, PA 15217-3025, United States',
#    'id': 'here:af:streetsection:1xU4yNJESZ-.XO7ndFQpMD:CgcIBCDT_JsgEAEaBDY1ODkoZA',
#    'resultType': 'houseNumber',
#    'houseNumberType': 'PA',
#    'address': {'label': '6589 Rosemoor St, Pittsburgh, PA 15217-3025, United States',
#     'countryCode': 'USA',
#     'countryName': 'United States',
#     'stateCode': 'PA',
#     'state': 'Pennsylvania',
#     'county': 'Allegheny',
#     'city': 'Pittsburgh',
#     'district': 'Squirrel Hill South',
#     'street': 'Rosemoor St',
#     'postalCode': '15217-3025',
#     'houseNumber': '6589'},
#    'position': {'lat': 40.42294, 'lng': -79.92061},
#    'access': [{'lat': 40.4227, 'lng': -79.92073}],
#    'mapView': {'west': -79.92179,
#     'south': 40.42204,
#     'east': -79.91943,
#     'north': 40.42384},
#    'scoring': {'queryScore': 0.82,
#     'fieldScore': {'state': 1.0,
#      'city': 1.0,
#      'streets': [1.0],
#      'houseNumber': 1.0,
#      'postalCode': 1.0}}}]}

# %%
# dump these responses to a json file so you won't have to rerun the geocoder api if you need more info from them
with open(r'geocode_api_responses.json', 'w') as f:
    json.dump(geocode_responses, f)

# %%
# code to read it back in, in case you need it later
with open(r"geocode_api_responses.json", "r") as read_file:
    data = json.load(read_file)

# %%
#

# %%
#create blank lists to store results, also store the address as the geocoder recognized it
#in case you need to diagnose errors later
lng_list = []
lat_list = []
recognized_addresses = []

# parse geocode responses. This retrieves 
for x in geocode_responses:
    # extract the lat and lon, and append them to the list
    try:
        lng_list.append(x['items'][0]['position']['lng'])
        lat_list.append(x['items'][0]['position']['lat'])
        recognized_addresses.append(x['items'][0]['address']['label'])
        
    except:
        # if the geocoder did not return a result, just append 0
        lng_list.append(0)
        lat_list.append(0)
        recognized_addresses.append('N/A')

# add these lists as columns to your original dataset
#voters['lon'] = lng_list
#voters['lat'] = lat_list
#voters['geocoder_recognized_address'] = recognized_addresses

# add these lists as columns using just the test bits
votersample = voters.iloc[:10,:]
votersample['lon'] = lng_list
votersample['lat'] = lat_list
votersample['geocoder_recognized_address'] = recognized_addresses
# Out:
# <ipython-input-21-390fd68ece82>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votersample['lon'] = lng_list
# <ipython-input-21-390fd68ece82>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votersample['lat'] = lat_list
# <ipython-input-21-390fd68ece82>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votersample['geocoder_recognized_address'] = recognized_addresses

# %%
votersample
# Out:
#              ID IsActive                 Name  \
# 0  001384287-02        A      EDWARD T LEHENY
# 1  001395718-02        I  LAWRENCE J ZIGERELL
# 2  001405849-02        A          JOHN W MADL
# 3  001595964-02        A    JEFFREY A SCHWARZ
# 4  001530986-02        I    PAUL JOYA ALARCON
# 5  001919470-02        A    FRANCIS E FAIRMAN
# 6  001919955-02        A  WILLIAM P KRAKOVSKY
# 7  001912448-02        A      RAYMOND H SMITH
# 8  001539723-02        A  ARNOLD E BURCHIANTI
# 9  001921302-02        A       HENRY E HALLER
#
#                                              Address      Home Phone  \
# 0  6589  ROSEMOOR ST APT. UPPR\nPITTSBURGH, PA  1...             NaN
# 1            5700  CENTRE AVE\nPITTSBURGH, PA  15206  (724) 561-5280
# 2            4136  BRISTOL ST\nPITTSBURGH, PA  15207             NaN
# 3              306  SALINE ST\nPITTSBURGH, PA  15207             NaN
# 4         6310  DARLINGTON RD\nPITTSBURGH, PA  15217             NaN
# 5           719  AMBERSON AVE\nPITTSBURGH, PA  15232             NaN
# 6         938  GREENFIELD AVE\nPITTSBURGH, PA  15217  (412) 421-9175
# 7    825  MOREWOOD AVE APT. D\nPITTSBURGH, PA  15213             NaN
# 8              1074  DEVON RD\nPITTSBURGH, PA  15213             NaN
# 9               5615  HOWE ST\nPITTSBURGH, PA  15232  (412) 361-6797
#
#   Registration\nDate         DOB Party     County       lon       lat  \
# 0         10/07/1996  08/23/1978     D  ALLEGHENY -79.92061  40.42294
# 1         02/27/1992  11/19/1973     R  ALLEGHENY -79.93346  40.45701
# 2         01/13/1997  12/17/1954     R  ALLEGHENY -79.94644  40.42220
# 3         09/26/2003  09/17/1975     D  ALLEGHENY -79.94825  40.42696
# 4         10/08/2002  09/28/1944     R  ALLEGHENY -79.91876  40.43689
# 5         08/01/1968  05/30/1923     R  ALLEGHENY -79.93960  40.44990
# 6         02/01/1968  12/04/1946    NF  ALLEGHENY -79.93210  40.42348
# 7         09/01/1964  01/27/1943     D  ALLEGHENY -79.94202  40.44841
# 8         06/18/1998  06/15/1970     R  ALLEGHENY -79.94065  40.44565
# 9         09/01/1968  02/25/1947    LN  ALLEGHENY -79.93116  40.45126
#
#                          geocoder_recognized_address
# 0  6589 Rosemoor St, Pittsburgh, PA 15217-3025, U...
# 1  5700 Centre Ave, Pittsburgh, PA 15206-3708, Un...
# 2  4136 Bristol St, Pittsburgh, PA 15207-1480, Un...
# 3  306 Saline St, Pittsburgh, PA 15207-1032, Unit...
# 4  6310 Darlington Rd, Pittsburgh, PA 15217-1836,...
# 5  719 Amberson Ave, Pittsburgh, PA 15232-1401, U...
# 6  938 Greenfield Ave, Pittsburgh, PA 15217-2631,...
# 7  825 Morewood Ave, Pittsburgh, PA 15213-2900, U...
# 8  1074 Devon Rd, Pittsburgh, PA 15213-3802, Unit...
# 9  5615 Howe St, Pittsburgh, PA 15232-2415, Unite...

# %%
# export updated voters file
#voters.to_csv("geocoded_voter_data.csv")

# export updated voters file
votersample.to_csv("geocoded_sample_data.csv")
